# %%
import sys
sys.path.append('/home/trukhinmaksim/src')
from random import sample
import numpy as np
import matplotlib.pyplot as plt

# %%
size = (7,5)

# %%
X = np.arange(1, 28)
Y = [
2.081396214942789e-68,
1,
0.07538113659350068,
1,
0,
0.31764982974994993,
1.4754058443439642e-33,
1,
9.266211990274998e-279,
2.2557660918982553e-125,
9.093895865986453e-270,
1.785369151647881e-224,
0.8191614124847737,
0,
1,
1,
0.9999755960172428,
6.0405240252331e-47,
0,
0.0009185840373628426,
1.7271649223883904e-56,
1,
0,
5.975768624052883e-07,
1.6499472812977771e-220,
0,
7.735330982498752e-34
]
Y = np.array(Y)
plt.figure(figsize=size) # Set the figure size for better readability
plt.plot(X, Y, marker='o', linestyle='-') # Plot the data
#plt.title('Doc2Vec autotuninig with Eucledian distance on projects similarity task') # Set the title of the plot
plt.xlabel('Autotuner iterations') # Label for the X-axis
plt.ylabel('U test values') # Label for the Y-axis
plt.grid(False) # Add a grid for easier reading of values
plt.xticks(X) # Ensure all x-axis ticks are shown if 26 values
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig("/home/trukhinmaksim/src/results/plots/Doc2Vec_neg_euclidean.png")
plt.show() # Display the plot

# %%
#plt.savefig("/home/trukhinmaksim/src/results/plots/Doc2Vec_neg_euclidean.png")

# %%
X = np.arange(1, 28)
Y = [
    8.531634112204394e-213,
1,
0,
1,
7.274533463847299e-102,
9.640850555104447e-142,
0,
1,
1,
7.923472675670835e-25,
0,
6.48321653772599e-81,
1.2941168480428695e-18,
0.1556488287496114,
1,
4.80984420011573e-56,
0,
1.0922323803025408e-148,
9.136771340016417e-188,
0,
2.0874718864932857e-31,
0,
0,
0,
1.3102452303192948e-54,
0.9186302834223606,
3.6423869930224713e-225
]
Y = np.array(Y)
plt.figure(figsize=(7, 5)) # Set the figure size for better readability
plt.plot(X, Y, marker='o', linestyle='-') # Plot the data
#plt.title('Doc2Vec autotuninig with cosine similarity on projects similarity task') # Set the title of the plot
plt.xlabel('Autotuner iterations') # Label for the X-axis
plt.ylabel('U test values') # Label for the Y-axis
plt.grid(False) # Add a grid for easier reading of values
plt.xticks(X) # Ensure all x-axis ticks are shown if 26 values
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig("/home/trukhinmaksim/src/results/plots/Doc2Vec_cos.png")
plt.show() # Display the plot

# %%
data = [
(0.6411, 0.6472, 0.6338),
(0.5978, 0.6488, 0.6315),
(0.5625, 0.6724, 0.6067),
(0.5355, 0.6593, 0.6238),
(0.5146, 0.6696, 0.6188),
(0.4974, 0.6745, 0.6221),
(0.4826, 0.6758, 0.6234),
]

X = np.arange(1, 8)
plt.figure(figsize=size) # Set the figure size for better readability
plt.plot(X, [t[0] for t in data], marker='o', linestyle='-', label = "train loss") # Plot the data
plt.plot(X, [t[1] for t in data], marker='o', linestyle='-', color = "red", label = "evaluation loss")
plt.plot(X, [t[2] for t in data], marker='o', linestyle='-', color = "orange", label = "accuracy")
#plt.title('BERT model training on projects similarity task') # Set the title of the plot
plt.legend()
plt.xlabel('Epochs') # Label for the X-axis
plt.ylabel('Loss & accuracy') # Label for the Y-axis
plt.grid(False) # Add a grid for easier reading of values
plt.xticks(X) # Ensure all x-axis ticks are shown if 26 values
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig("/home/trukhinmaksim/src/results/plots/bert_train.png")
plt.show() # Display the plot
