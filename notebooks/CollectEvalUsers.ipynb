# %%
import sys
sys.path.append('/home/trukhinmaksim/src')
from random import sample

# %%
from src.utils.DatasetManager import DatasetManager#, NewDatasetManager, RawTextDatasetManager
#from src.utils.DatabaseConnect import DatabaseConnector, CacheConnector
from src.utils.CacheAdapter import EXP_END_OF_DATA, FlatAdapter
from src.data_processing.scan_csv_files import UsersEvaluationAdapter
from src.utils.validators import projectDataIsHighQuality, userProjectsIsHighQuality

#Wang_laoshi_connector = DatabaseConnector("mongodb://readonlyUser:cictest123456@114.212.84.247:27017/", "developer_discovery").collection("proj_info")

PRIORITY_CSV_FILES = [
    "user_profiles_github_23mf_react-native-translucent-modal.csv",
    "user_profiles_github_2017398956_react-native-textinput-maxlength-fixed.csv",
    "user_profiles_github_a7ul_react-native-exception-handler.csv",
    "user_profiles_github_afollestad_material-dialogs.csv"
]

inputAdapter = UsersEvaluationAdapter(PRIORITY_CSV_FILES)

#collection = CacheConnector("mongodb://10.22.80.194:27020/").collection("cache_21-04-25")
#outputDB = DBFlatAdapter(collection)
outputCache = FlatAdapter("/home/trukhinmaksim/src/data/cache_21-04-25/users_evaluation_21-04-25")

#manager.readInput()

# %%
class Counter:
    def __init__(self, *args, **kwargs):
        self.counter = 0
        self.iteration = 0
        self.users = []

    def save(self, users):
        self.counter += len(users)
        self.users.extend(users)
        self.iteration += 1
        print(f"Collected {self.counter} high quality users in {self.iteration} iterations")

manager = DatasetManager(
    1,
    inputAdapter = inputAdapter, 
    outputAdapters = [Counter()],
    validator = userProjectsIsHighQuality
)

manager()
#manager.mapper = mapper
#manager.blackList = BlackList()
# Out:
# Reading file  user_profiles_github_23mf_react-native-translucent-modal.csv
# Collected 10 high quality users in 1 iterations

# %%
manager.outputAdapters[0].users
# Out:
# [{'id': 'github:madf12',
#   'type': 'B',
#   'projects': {'github:BeTomorrow/react-native-file-logger': 'react-native-file-logger. A simple file-logger for React Native with configurable rolling policy, based on CocoaLumberjack on iOS and Logback on Android.',
#    'github:muratovic/lib-config': '',
#    'github:antonfisher/react-simple-timefield': 'react-simple-timefield. Simple React time input field',
#    'github:JustArchiNET/ASF-ui': 'ASF-ui. The official web interface for ASF',
#    'github:bipmeet/lib-bip-meet': '',
#    'github:typestack/class-transformer': 'class-transformer. Decorator-based transformation, serialization, and deserialization between objects and classes. ',
#    'github:madf12/react-native-file-logger': 'react-native-file-logger. A simple file-logger for React Native with configurable rolling policy, based on CocoaLumberjack on iOS and Logback on Android.',
#    'github:madf12/jitsi-meet': 'jitsi-meet. Jitsi Meet - Secure, Simple and Scalable Video Conferences that you use as a standalone app or embed in your web application.',
#    'github:madf12/react-simple-timefield': 'react-simple-timefield. Simple React time input field',
#    'github:madf12/placeholder-db': 'placeholder-db. A\xa0demo repository for My JSON Server (Alpha)',
#    'github:madf12/ASF-ui': 'ASF-ui. The official web interface for ASF'}},
#  {'id': 'github:hectorqin',
#   'type': 'B',
#   'projects': {'github:CareyToboo/ovine': 'ovine. ovine由于存在设计缺陷不再更新。 新版会在 ovine-next 重写。  https://github.com/ovineio/ovine-next',
#    'github:hectorqin/vscode-php-helper': 'vscode-php-helper. A php-helper plugin for vscode',
#    'github:hectorqin/reader': 'reader. 阅读3服务器版，桌面端，iOS可用。后端 Kotlin + Spring Boot + Vert.x + Coroutine ；前端 Vue.js + Element。麻烦点点star，关注一下公众号【假装大佬】❗️  ',
#    'github:hyperf/hyperf': 'hyperf. 🚀 A coroutine framework that focuses on hyperspeed and flexibility. Building microservice or middleware with ease.',
#    'github:aooiuu/z-reader': 'z-reader. 📘 [vscode插件] 小说阅读器,支持在线搜索和本地阅读,支持txt和epub格式',
#    'github:hectorqin/reverse-engineering': '',
#    'github:baidu/amis': 'amis. 前端低代码框架，通过 JSON 配置就能生成各种页面。',
#    'github:Hunlongyu/ZY-Player': 'ZY-Player. ▶️ 跨平台桌面端视频资源播放器.简洁无广告.免费高颜值. 🎞',
#    'github:hyperf/di': '',
#    'github:hectorqin/hyperf': 'hyperf. 🚀A coroutine framework that focuses on hyperspeed and flexibility. Building microservice or middleware with ease.',
#    'github:shuding/nextra': 'nextra. Simple, powerful and flexible site generation framework with everything you love from Next.js.',
#    'github:hectorqin/hyper-reorderable-tabs': 'hyper-reorderable-tabs. Draggable tabs suport for Hyper Terminal',
#    'github:leizongmin/vscode-quick-open': 'vscode-quick-open. Visual Studio Code plugin that provide a quick open file command',
#    'github:hectorqin/think-core': '',
#    'github:hectorqin/hectorqin.github.io': 'hectorqin.github.io. My blog',
#    'github:hectorqin/react-native-rn-videoplayer': 'react-native-rn-videoplayer. 基于react-native-video的视频播放器（上下滑动改变音量屏幕亮度，缓存进度，双击暂停等ios Android）',
#    'github:hectorqin/hyper-helper': '',
#    'github:hectorqin/antcloud-php-sdk': 'antcloud-php-sdk. antcloud',
#    'github:hectorqin/jsfun-anyproxy': 'jsfun-anyproxy. Anyproxy for android on JSFun platform',
#    'github:hectorqin/nodejs-mobile-react-native': 'nodejs-mobile-react-native. Node.js for Mobile Apps React Native plugin',
#    'github:hectorqin/whistlern': '',
#    'github:hectorqin/ZY-Player': 'ZY-Player. ▶️ 跨平台桌面端视频资源播放器.简洁无广告.免费高颜值. 🎞',
#    'github:hectorqin/ovine': 'ovine. Build entirety admin system ui blazing fast with json.',
#    'github:hectorqin/php-resque': 'php-resque. php-resque for ThinkPHP5/6, ThinkPHP3.2',
#    'github:hectorqin/mproxy': 'mproxy. Simple HTTP Proxy with basic authentication, support simple reverse proxy',
#    'github:hectorqin/phpmon': 'phpmon. 🚀 Hyperf Watch Hot Reload Scripts  😊 Just like nodemon  👉 监听文件变化自动重启Hyperf',
#    'github:hectorqin/z-reader': 'z-reader. 📘 [vscode插件] 小说阅读器,支持在线搜索和本地阅读,支持txt和epub格式',
#    'github:hectorqin/hyperf-thinkphp': 'hyperf-thinkphp. hyperf',
#    'github:hectorqin/hyperf-generator': 'hyperf-generator. hyperf generator',
#    'github:hectorqin/hyperterm-overlay': 'hyperterm-overlay. A complete and customizable solution for a overlay window in your Hyper.app',
#    'github:hectorqin/local-echo': 'local-echo. A local-echo controller for xterm.js',
#    'github:hectorqin/amis': 'amis. 前端低代码框架，通过 JSON 配置就能生成各种后台页面。',
#    'github:hectorqin/hyper': 'hyper. A terminal built on web technologies',
#    'github:hectorqin/react-native-alarm-notification': 'react-native-alarm-notification. schedule alarm and local notification in react-native',
#    'github:hectorqin/JSFun-releases': 'JSFun-releases. JSFun releases for all platform',
#    'github:hectorqin/react-native-vpn2sock': 'react-native-vpn2sock. vpn2socks package for react-native. Not support IOS currently.',
#    'github:hectorqin/di': '',
#    'github:hectorqin/iterm2-scp': 'iterm2-scp. Iterm2 scp helper script. Use scp command to conveniently upload file to server and download file from server',
#    'github:hectorqin/nextra': 'nextra. The Next.js Static Site Generator',
#    'github:hectorqin/vscode-quick-open': 'vscode-quick-open. Visual Studio Code plugin that provide a quick open file command',
#    'github:hectorqin/vscode-quick-open-plus': '',
#    'github:hectorqin/hectorqin': '',
#    'github:hectorqin/think-generate': 'think-generate. think-generate',
#    'github:hectorqin/hyperf-fastloader': 'hyperf-fastloader. Make hyperf2.0 load faster',
#    'github:hectorqin/react-native-material-dialog': 'react-native-material-dialog. Material design dialogs for React Native 💬',
#    'github:hectorqin/react-native-file-selector': 'react-native-file-selector. React Native: Native File Selector',
#    'github:hectorqin/lightink-server': 'lightink-server. lightink-小说API(书源模式),目前支持100+网站的解析. vertx + kotlin + coroutine(协程)',
#    'github:hectorqin/cydia-repo': '',
#    'github:hectorqin/JDSignAction': '',
#    'github:hectorqin/hyperf-watch': '',
#    'github:hectorqin/articles': '',
#    'github:hectorqin/JSONDrivenUINew': ''}},
#  {'id': 'github:Redseb',
#   'type': 'B',
#   'projects': {'github:software-mansion/react-native-reanimated': "react-native-reanimated. React Native's Animated library reimplemented",
#    'github:Redseb/DrinkUp': 'DrinkUp. A fun drinking game written in React Native and Reanimated',
#    'github:ReactNativeNews/React-Native-Apps': 'React-Native-Apps. Curated List of Open Source React Native Apps.  Curation curtesy of',
#    'github:Redseb/izyzanski.github.io': '',
#    'github:procek69/pjatk-the-burning-tomaszew': '',
#    'github:Max-7th-byte/calculusCalculator': '',
#    'github:izyzanski/izyzanski.github.io': '',
#    'github:deanhet/react-native-text-ticker': 'react-native-text-ticker. React Native Text Ticker/Marquee Component',
#    'github:Redseb/Problemon': 'Problemon. Problemon, a calculus Pokemon-like game built with React Native',
#    'github:Redseb/beerApi': 'beerApi. A RESTful Beer API built with Node.js Express and MongoDB',
#    'github:ajsmth/react-native-pager': 'react-native-pager. controllable pager component for react native',
#    'github:expo/expo': 'expo. An open-source framework for making universal native apps with React. Expo runs on Android, iOS, and the web.',
#    'github:Redseb/phasmophobia-companion': 'phasmophobia-companion. An unofficial companion app to the amazing horror game by Kinetic Games, Phasmophobia.',
#    'github:Redseb/redseb.github.io': 'redseb.github.io. Portfolio hosting!',
#    'github:Redseb/pjatk-the-burning-tomaszew': '',
#    'github:Redseb/Culture-Power-Solutions-site': '',
#    'github:Redseb/TIN': 'TIN. Assignments for the TIN course',
#    'github:Redseb/civ5Randomizer': 'civ5Randomizer. Web app used to randomize Civilization 5 playthroughs',
#    'github:Redseb/weather-app': 'weather-app. A React Native weather app built using TS and MobX',
#    'github:sickcash/sickcash.github.io': '',
#    'github:Redseb/biedronkaPlus': 'biedronkaPlus. A better version of the "Twoja Biedronka" app',
#    'github:Redseb/React-Native-Apps': 'React-Native-Apps. Curated List of Open Source React Native Apps.  Curation curtesy of',
#    'github:Redseb/blackPinkNewTab': '',
#    'github:Redseb/BYT': 'BYT. BYT Assignments',
#    'github:Redseb/BYT-9-10': 'BYT-9-10. BYT 9&10 implementation of the class diagram',
#    'github:Redseb/FileViewer': 'FileViewer. Due to macOS not allowing audio sharing while screen sharing, this web app functions as a work around as Google Chrome allows for audio sharing and screen sharing but only from one tab.',
#    'github:Redseb/soundboardTemplate': 'soundboardTemplate. React Native Soundboard Template',
#    'github:Redseb/Redseb': '',
#    'github:Redseb/react-native-text-ticker': 'react-native-text-ticker. React Native Text Ticker/Marquee Component',
#    'github:Redseb/messengerDarkMode': 'messengerDarkMode. Finally a dark messenger theme',
#    'github:Redseb/chrome-themes': 'chrome-themes. A collection of custom made chrome-themes',
#    'github:Redseb/xbox-games-with-gold-back': '',
#    'github:Redseb/react-gameoflife': "react-gameoflife. A simple simulation of Conway's Game of Life.",
#    'github:Redseb/Linux-Cyber-Security-Notes': '',
#    'github:Redseb/calculusCalculator': '',
#    'github:Redseb/TicEdToe': 'TicEdToe. A 1 hour game making challenge by DevEd in which I made tic tac toe in React Native',
#    'github:Redseb/xbox-games-with-gold-front': '',
#    'github:orka97/Byt10': 'Byt10. BYT tutorial',
#    'github:Redseb/react-native-pager': 'react-native-pager. controllable pager component for react native',
#    'github:Redseb/react-native-reanimated': "react-native-reanimated. React Native's Animated library reimplemented",
#    'github:Redseb/expo': 'expo. An open-source platform for making universal native apps with React. Expo runs on Android, iOS, and the web.'}},
#  {'id': 'github:anhquan291',
#   'type': 'B',
#   'projects': {'github:anhquan291/milkteapp': '',
#    'github:xcarpentier/react-native-country-picker-modal': 'react-native-country-picker-modal. 🇦🇶 Country picker provides a modal allowing a user to select a country from a list. It display a flag next to each country name.',
#    'github:anhquan291/frontendStoneStore': 'e-commerce-app-react-native. E-commerce App UI. React native, Expo managed flow, React navigation v5, Notification.',
#    'github:anhquan291/e-commerce-app-react-native': 'e-commerce-app-react-native. E-commerce App UI. React native, Expo managed flow, React navigation v5, Notification.',
#    'github:anhquan291/Pokedex': '',
#    'github:anhquan291/backendStoneApp': 'e-commerce-app-backend. Backend For Stone App. Nodejs, Express, JWT, Mongodb, Mongoose, Stripe, Expo ',
#    'github:anhquan291/-e-commerce-app-backend': '',
#    'github:anhquan291/code-base-2022': '',
#    'github:anhquan291/FrontendStoneStore': '',
#    'github:anhquan291/RNCardScan': '',
#    'github:anhquan291/react-native-image-gallery': 'react-native-image-gallery. Pure JavaScript image gallery component for iOS and Android with high-performance and native feeling in mind',
#    'github:anhquan291/react-native-calendar-strip': 'react-native-calendar-strip. Easy to use and visually stunning calendar component for React Native.',
#    'github:anhquan291/react-native-multiple-image-picker': 'react-native-multiple-image-picker. react-native-multiple-image-picker enables application to pick images and videos from multiple smart album in iOS, similar to the current facebook app.',
#    'github:anhquan291/igate-review': '',
#    'github:anhquan291/anhquan291': '',
#    'github:anhquan291/React-SW-BS-SC-RD-Template': '',
#    'github:anhquan291/milktea_app': '',
#    'github:anhquan291/e-commerce-app-backend': 'e-commerce-app-backend. Backend For Stone App. Nodejs, Express, JWT, Mongodb, Mongoose, Stripe, Expo ',
#    'github:anhquan291/react-native-country-picker-modal': 'react-native-country-picker-modal. 🇦🇶 Country picker provides a modal allowing a user to select a country from a list. It display a flag next to each country name.',
#    'github:anhquan291/SpaLandingPage': 'SpaLandingPage. Spa landing page. ',
#    'github:anhquan291/BakeryUI': '',
#    'github:anhquan291/GalleryPhotographer': '',
#    'github:anhquan291/BackendStoneApp': '',
#    'github:anhquan291/react-native-image-viewing': 'react-native-image-viewing. Tiny, purely TS, modal component for viewing images 🏙 ',
#    'github:anhquan291/react-native-video-controls': 'react-native-video-controls. A React Native video component with controls',
#    'github:anhquan291/milktea_admin': '',
#    'github:anhquan291/testingLayout': ''}},
#  {'id': 'github:MohamadKh75',
#   'type': 'B',
#   'projects': {'github:th3rdwave/react-native-safe-area-context': 'react-native-safe-area-context. A flexible way to handle safe area insets in JS. Also works on Android and Web! ',
#    'github:MohamadKh75/react-native-jalali-datepicker': 'react-native-jalali-datepicker. 📅 React Native Jalali DatePicker component for both Android and iOS ✨',
#    'github:serhii-londar/open-source-mac-os-apps': 'open-source-mac-os-apps. 🚀 Awesome list of open source applications for macOS. https://t.me/s/opensourcemacosapps',
#    'github:rbrahul/Awesome-JSON-Viewer': 'Awesome-JSON-Viewer. :fire: A Chrome extension to visualise JSON response and  introduce awesome JSON prettifying experiences.',
#    'github:shimuldn/hCaptchaSolverApi': 'NoCaptcha-Ai-Browser-Extension. qCAPTCHA Solver, reCaptcha v2, OCR Captcha. Chrome-Firefox Extension',
#    'github:MohamadKh75/react-native-animated-ruler': 'react-native-animated-ruler. :triangular_ruler: Customizable animated ruler for react-native :straight_ruler: :sparkles:',
#    'github:MohamadKh75/react-navigation-transition-config': 'react-navigation-transition-config. Custom transition config for react-navigation',
#    'github:MohamadKh75/TF61': '',
#    'github:PKief/vscode-material-icon-theme': 'vscode-material-icon-theme. Available on the VSCode Marketplace',
#    'github:filipemerker/flatlist-performance-tips': 'flatlist-performance-tips. 📱 Tips and tricks to improve your React Native FlatList performance and memory consumption',
#    'github:deanhet/react-native-text-ticker': 'react-native-text-ticker. React Native Text Ticker/Marquee Component',
#    'github:react-navigation/react-navigation.github.io': 'react-navigation.github.io. Home of the documentation and other miscellanea',
#    'github:facebook/react-native-website': 'react-native-website. The React Native website and docs',
#    'github:MohamadKh75/iOS_Development_Certificates': 'iOS_Development_Certificates. 📱🛠 iOS Development Certificates',
#    'github:invertase/react-native-firebase': 'react-native-firebase. 🔥 A well-tested feature-rich modular Firebase implementation for React Native. Supports both iOS & Android platforms for all Firebase services.',
#    'github:emeraldsanto/react-native-encrypted-storage': 'react-native-encrypted-storage. React Native wrapper around EncryptedSharedPreferences and Keychain to provide a secure alternative to Async Storage.',
#    'github:maritome/cypress-msteams-reporter': '',
#    'github:gram-js/gramjs': 'gramjs. NodeJS/Browser MTProto API Telegram client library,',
#    'github:seniv/react-native-notifier': 'react-native-notifier. Fast and simple in-app notifications for React Native',
#    'github:cypress-io/cypress-documentation': 'cypress-documentation. Cypress Documentation for the Cypress App, API, Cypress Cloud, UI Coverage and Cypress Accessibility.',
#    'github:RobertBroersma/bigheads': 'beanheads. Easily create characters for your projects',
#    'github:react-native-community/async-storage': 'async-storage. An asynchronous, persistent, key-value storage system for React Native.',
#    'github:Windscribe/Desktop-App': 'Desktop-App. Windscribe 2.0 desktop client for Windows, Mac and Linux',
#    'github:react-native-community/directory': 'directory. A searchable and filterable directory of React Native libraries.',
#    'github:MohamadKh75/dotfiles': 'dotfiles. My configurations ⚙️',
#    'github:MohamadKh75/project-template': 'project-template. My project template in TS 💙',
#    'github:MohamadKh75/project-template-cli': 'project-template-cli. Create projects easier 🪄',
#    'github:MohamadKh75/open-source-mac-os-apps': '',
#    'github:noCaptchaAi/nocaptchaai-puppeteer': 'nocaptchaai-puppeteer. Puppeteer package for NoCaptchaAI (qCaptcha solver) ⚡️',
#    'github:MohamadKh75/Awesome-JSON-Viewer': '',
#    'github:MohamadKh75/hCaptchaSolverApi': "hCaptchaSolverApi. Takes ~ 0.04s/solve Blazing fast hCaptcha solver based on NeuralNet image detection AI. noCapcthaAi is scaleable and robust so you can throw any kind of load. It's as simple as send base64 images post request and get solved response. We're adding reCaptcha, geetest etc soon. https://discord.gg/E7FfzhZqzA",
#    'github:MohamadKh75/MohamadKh75': '',
#    'github:MohamadKh75/flatlist-performance-tips': '',
#    'github:MohamadKh75/react-native-safe-area-context': '',
#    'github:MohamadKh75/react-native-text-ticker': '',
#    'github:MohamadKh75/husky': 'husky. Git hooks made easy 🐶 woof!',
#    'github:MohamadKh75/QA_Code_Challenge': '',
#    'github:MohamadKh75/react-navigation.github.io': '',
#    'github:MohamadKh75/react-native-website': '',
#    'github:MohamadKh75/react-native-firebase': '',
#    'github:MohamadKh75/react-native-encrypted-storage': '',
#    'github:MohamadKh75/why-make': 'why-make. A deep dive into why tech projects get built',
#    'github:MohamadKh75/cypress-msteams-reporter': '',
#    'github:MohamadKh75/resume': 'resume. My Resume 🎉',
#    'github:MohamadKh75/gramjs': 'gramjs. NodeJS/Browser MTProto API Telegram client library,',
#    'github:MohamadKh75/vscode-material-icon-theme': 'vscode-material-icon-theme. Available on the VSCode Marketplace',
#    'github:MohamadKh75/react-native-notifier': '',
#    'github:MohamadKh75/cypress-documentation': 'cypress-documentation. Cypress Documentation including Guides, API, Plugins, Examples, & FAQ.',
#    'github:MohamadKh75/bigheads': '',
#    'github:MohamadKh75/ReactNativeNotes': 'ReactNativeNotes. My notes about React Native',
#    'github:MohamadKh75/TabBarBugDemo': '',
#    'github:MohamadKh75/async-storage': '',
#    'github:MohamadKh75/Desktop-App': 'Desktop-App. Windscribe 2.0 desktop client for Windows, Mac and Linux',
#    'github:MohamadKh75/ites-cypress': 'ites-cypress. ITES first meeting - Cypress Live Coding 🧪',
#    'github:MohamadKh75/directory': ''}},
#  {'id': 'github:TPXP',
#   'type': 'B',
#   'projects': {'github:Layton-Community/Layton-Fangame': "Ravens-Curse. The repository of the fangame Professor Layton and the Raven's Curse built with the Godot Engine.",
#    'github:redis-developer/redis-developer.github.io': 'redis-developer.github.io. The Home of Redis Developers',
#    'github:invertase/react-native-firebase': 'react-native-firebase. 🔥 A well-tested feature-rich modular Firebase implementation for React Native. Supports both iOS & Android platforms for all Firebase services.',
#    'github:jenkins-infra/jenkins.io': 'jenkins.io. A static site for the Jenkins automation server',
#    'github:strapi/strapi': 'strapi. 🚀 Strapi is the leading open-source headless CMS. It’s 100% JavaScript/TypeScript, fully customizable, and developer-first.',
#    'github:golang/pkgsite': 'pkgsite. [mirror] Home of the pkg.go.dev website',
#    'github:MarketSquare/webdrivermanager': 'webdrivermanager. Python module to facilitate downloading and deploying WebDriver binaries for Chrome, Firefox, Opera & Edge',
#    'github:tinycreative/react-native-intercom': 'react-native-intercom. React Native wrapper for Intercom.io',
#    'github:kozec/syncthing-gtk': 'syncthing-gtk. GTK3 & python based GUI for Syncthing',
#    'github:firebase/firebase-tools': 'firebase-tools. The Firebase Command Line Tools',
#    'github:serverless/platform-sdk': '',
#    'github:facebook/react-native-website': 'react-native-website. The React Native website and docs',
#    'github:echo-devim/fhex': 'fhex. A Full-Featured HexEditor compatible with Linux/Windows/MacOS',
#    'github:lypnol/adventofcode-2021': '',
#    'github:alexpevzner/sane-airscan': 'sane-airscan. Scanner Access Now Easy - universal driver for eSCL (Apple AirScan) and WSD',
#    'github:artf/grapesjs': 'grapesjs. Free and Open source Web Builder Framework. Next generation tool for building templates without coding',
#    'github:webpack/webpack.js.org': 'webpack.js.org. Repository for webpack documentation and more!',
#    'github:1bastien1/plant-OClock': '',
#    'github:php/doc-fr': 'doc-fr. French translation of the PHP documentation',
#    'github:traefik/traefik': 'traefik. The Cloud Native Application Proxy',
#    'github:showdownjs/showdown': 'showdown. A bidirectional Markdown to HTML to Markdown converter written in Javascript',
#    'github:EasyCorp/easy-deploy-bundle': 'easy-deploy-bundle. The easiest way to deploy your Symfony applications',
#    'github:elastic/kibana': 'kibana. Your window into the Elastic Stack',
#    'github:silverspectro/vue-clickaway2': '',
#    'github:react-native-community/react-native-blur': 'react-native-blur. React Native Blur component',
#    'github:axios/axios': 'axios. Promise based HTTP client for the browser and node.js',
#    'github:jpadilla/pyjwt': 'pyjwt. JSON Web Token implementation in Python',
#    'github:jenkinsci/gitlab-plugin': 'gitlab-plugin. A Jenkins plugin for interfacing with GitLab',
#    'github:serverless/enterprise-plugin': '',
#    'github:keras-team/keras-io': 'keras-io. Keras documentation, hosted live at keras.io',
#    'github:kreait/firebase-php': 'firebase-php. Unofficial Firebase Admin SDK for PHP',
#    'github:prscX/react-native-popover-menu': 'react-native-popover-menu. React Native: Native Popover Menu',
#    'github:ascoders/react-native-image-zoom': 'react-native-image-zoom. react native image pan and zoom',
#    'github:duckduckgo/zeroclickinfo-goodies': 'zeroclickinfo-goodies. DuckDuckGo Instant Answers based on Perl & JavaScript',
#    'github:form-data/form-data': 'form-data. A module to create readable `"multipart/form-data"` streams.  Can be used to submit forms and file uploads to other web applications. ',
#    'github:expo/expo': 'expo. An open-source framework for making universal native apps with React. Expo runs on Android, iOS, and the web.',
#    'github:flyerhq/react-native-link-preview': 'react-native-link-preview. Fully customizable preview of the URL extracted from the provided text.',
#    'github:react-native-webview/react-native-webview': 'react-native-webview. React Native Cross-Platform WebView',
#    'github:yamill/react-native-orientation': 'react-native-orientation. Listen to device orientation changes in react-native and set preferred orientation on screen to screen basis.',
#    'github:vuetifyjs/vuetify': 'vuetify. 🐉 Vue Component Framework',
#    'github:kristerkari/react-native-svg-transformer': 'react-native-svg-transformer. Import SVG files in your React Native project the same way that you would in a Web application.',
#    'github:TPXP/fhex': 'fhex. A Full-Featured HexEditor compatible with Linux/Windows/MacOS',
#    'github:TPXP/redis-developer.github.io': 'redis-developer.github.io. The Home of Redis Developers',
#    'github:TPXP/react-native-firebase': 'react-native-firebase. 🔥 A well-tested feature-rich modular Firebase implementation for React Native. Supports both iOS & Android platforms for all Firebase services.',
#    'github:TPXP/easy-deploy-bundle': 'easy-deploy-bundle. The easiest way to deploy your Symfony applications',
#    'github:TPXP/pkgsite': 'pkgsite. [mirror] Home of the pkg.go.dev website',
#    'github:TPXP/jenkins.io': 'jenkins.io. A static site for the Jenkins automation server',
#    'github:TPXP/strapi': 'strapi. 🚀 Open source Node.js Headless CMS to easily build customisable APIs',
#    'github:Layton-Fangame/Layton-Fangame': '',
#    'github:TPXP/kibana': 'kibana. Your window into the Elastic Stack',
#    'github:TPXP/webdrivermanager': 'webdrivermanager. Python module to facilitate downloading and deploying WebDriver binaries for Chrome, Firefox, Opera & Edge',
#    'github:TPXP/ExampleRNApp': 'ExampleRNApp. Test RN App, with an attempt at GH actions',
#    'github:TPXP/switchroot-nightlies': '',
#    'github:TPXP/react-native-intercom': 'react-native-intercom. React Native wrapper for Intercom.io',
#    'github:TPXP/platform-sdk': 'platform-sdk. Serverless Platform SDK',
#    'github:pgalbraith/chocolatey-packages': 'chocolatey-packages. A template to use when setting up to create packages both manual and automatic',
#    'github:TPXP/firebase-tools': 'firebase-tools. The Firebase Command Line Tools',
#    'github:TPXP/react-native-website': 'react-native-website. The site and docs for React Native',
#    'github:TPXP/bfmemes_generator': 'bfmemes_generator. A full-featured meme generator',
#    'github:TPXP/platformsh-symfony-template': '',
#    'github:TPXP/sane-airscan': 'sane-airscan. Scanner Access Now Easy - universal driver for eSCL (Apple AirScan) and WSD',
#    'github:TPXP/grapesjs': 'grapesjs. Free and Open source Web Builder Framework. Next generation tool for building templates without coding',
#    'github:TPXP/webpack.js.org': 'webpack.js.org. Repository for webpack documentation and more!',
#    'github:TPXP/showdown': 'showdown. A bidirectional Markdown to HTML to Markdown converter written in Javascript',
#    'github:TPXP/node': '',
#    'github:TPXP/webpack-is-not-that-hard': '',
#    'github:TPXP/plant-OClock': '',
#    'github:TPXP/doc-fr': 'doc-fr. French translation of the PHP documentation',
#    'github:TPXP/axios': 'axios. Promise based HTTP client for the browser and node.js',
#    'github:TPXP/enterprise-plugin': 'enterprise-plugin. The Serverless Framework Enterprise plugin',
#    'github:TPXP/firebase-php': 'firebase-php. Unofficial Firebase Admin SDK for PHP',
#    'github:TPXP/vue-clickaway2': '',
#    'github:TPXP/react-native-blur': 'react-native-blur. React Native Blur component',
#    'github:TPXP/pyjwt': 'pyjwt. JSON Web Token implementation in Python',
#    'github:TPXP/gitlab-plugin': 'gitlab-plugin. A Jenkins plugin for interfacing with GitLab',
#    'github:TPXP/CDash': 'CDash. An open source, web-based software testing server',
#    'github:TPXP/keras-io': 'keras-io. Keras documentation, hosted live at keras.io',
#    'github:TPXP/react-native-popover-menu': 'react-native-popover-menu. React Native: Native Popover Menu',
#    'github:TPXP/react-native-image-zoom': 'react-native-image-zoom. react native image pan and zoom',
#    'github:TPXP/aws-sdk-js-v3': 'aws-sdk-js-v3. Modularized AWS SDK for JavaScript.',
#    'github:TPXP/zeroclickinfo-goodies': 'zeroclickinfo-goodies. DuckDuckGo Instant Answers based on Perl & JavaScript'}},
#  {'id': 'github:EQuimper',
#   'type': 'B',
#   'projects': {'github:EQuimper/youtube-react-native-podcast-tutorial': '',
#    'github:EQuimper/VSC-React-Native-React-Redux-Snippets': 'VSC-React-Native-React-Redux-Snippets. Snippets for React and React-Native with a bit of Redux for es6/es7 user.',
#    'github:EQuimper/youtube-golang-podcast-project': '',
#    'github:EQuimper/course-golang-twittter-clone-graphql': 'course-golang-twittter-clone-graphql. Code source for https://store.equimper.com/build-a-twitter-clone-graphql-api-using-golang',
#    'github:EQuimper/react-native-design-utility': 'react-native-design-utility. Utility for building design system in react-native. Idea from TailwindCSS',
#    'github:EQuimper/docs.adonisjs.com': 'docs.adonisjs.com. 📚 Source code and documentation for the official docs website. ',
#    'github:laravel-filament/filament': 'filament. A collection of beautiful full-stack components for Laravel. The perfect starting point for your next app. Using Livewire, Alpine.js and Tailwind CSS.',
#    'github:AppAndFlow/react-native-google-autocomplete': 'react-native-google-autocomplete. A hook that simplifies using the Google Places Autocomplete API.',
#    'github:EQuimper/rn-podcast-app': 'rn-podcast-app. This is the repos of the podcast app we build in live stream using React-Native',
#    'github:gofiber/fiber': 'fiber. ⚡️ Express inspired web framework written in Go',
#    'github:EQuimper/youtube-golang-graphql-tutorial': 'youtube-golang-graphql-tutorial. Repos for my youtube tutorial for graphql with golang',
#    'github:EQuimper/nodejs-api-boilerplate': 'nodejs-api-boilerplate. A boilerplate for kickstart your nodejs api project with JWT Auth and some new Techs :)',
#    'github:EQuimper/equimper.com': '',
#    'github:EQuimper/ent-go-demo': '',
#    'github:EQuimper/node-twitter-api-clone-demo': '',
#    'github:EQuimper/react-native-modalize': 'react-native-modalize. A highly customizable modal/bottom sheet that loves scrolling content.',
#    'github:EQuimper/filament': 'filament. The elegant TALL stack admin for Laravel artisans.',
#    'github:EQuimper/nhl_stats_api': 'nhl_stats_api. Unofficial, Go API for the nhl api.',
#    'github:EQuimper/react-native-set-app-icon': '',
#    'github:EQuimper/fiber': 'fiber. ⚡️ Fiber is an Express inspired web framework written in Go with ☕️',
#    'github:EQuimper/youtube-golang-nhl-project': '',
#    'github:EQuimper/tweet-clone': '',
#    'github:EQuimper/youtube-go-fiber-introduction': 'youtube-go-fiber-introduction. An introduction to Fiber an express-like library for golang',
#    'github:EQuimper/blog': ''}},
#  {'id': 'github:MikeChugunov',
#   'type': 'B',
#   'projects': {'github:joltup/rn-fetch-blob': 'rn-fetch-blob. A project committed to making file access and data transfer easier, efficient for React Native developers.',
#    'github:dpa99c/react-native-launch-navigator': "react-native-launch-navigator. A React Native module for launching today's most popular navigation/ride apps to navigate to a destination.",
#    'github:Swifteroid/Slang': '',
#    'github:ReactiveCocoa/ReactiveSwift': 'ReactiveSwift. Streams of values over time',
#    'github:Swifteroid/ReactiveOAuth': 'ReactiveOAuth. OAuthSwift + ReactiveSwift = 🦄💖',
#    'github:MikeChugunov/rn-fetch-blob': 'rn-fetch-blob. A project committed to making file access and data transfer easier, efficient for React Native developers.',
#    'github:MikeChugunov/Opencore-ASUS-Z370A': 'Opencore-ASUS-Z370A. An Opencore 0.7.0 configuration for ASUS-Z370A',
#    'github:MikeChugunov/ReactiveSwift': 'ReactiveSwift. Streams of values over time',
#    'github:MikeChugunov/ezcache': 'ezcache. Easy to use caching for GitHub Actions',
#    'github:MikeChugunov/react-native-launch-navigator': "react-native-launch-navigator. A React Native module for launching today's most popular navigation/ride apps to navigate to a destination.",
#    'github:MikeChugunov/ThemeKit': 'ThemeKit. macOS theming library',
#    'github:MikeChugunov/shell': 'shell. 🧪 Shell is a µ-library written in Swift to run system commands',
#    'github:MikeChugunov/background-geolocation-android': '',
#    'github:MikeChugunov/react-native-background-geolocation': 'react-native-background-geolocation. Background and foreground geolocation plugin for React Native. Tracks user when app is running in background.'}},
#  {'id': 'github:452MJ',
#   'type': 'B',
#   'projects': {'github:ZhangTaoK/react-native-marquee-ab': 'react-native-marquee-ab. react-native 水平/竖直滚动跑马灯。支持多个text数据，支持点击事件回调，自定义宽度、样式。',
#    'github:syanbo/react-native-syan-image-picker': 'react-native-syan-image-picker. React-Native 多图片选择 支持裁剪 压缩',
#    'github:DylanVann/react-native-fast-image': 'react-native-fast-image. 🚩 FastImage, performant React Native image component.',
#    'github:JesperLekland/react-native-svg-charts-examples': 'react-native-svg-charts-examples. A collection of usage examples of react-native-svg-charts',
#    'github:ant-design/ant-design-mobile-rn': 'ant-design-mobile-rn. Ant Design for React Native',
#    'github:452MJ/react-native-template': "react-native-template. Jerry's react-native-template",
#    'github:452MJ/jmessage-react-plugin': '',
#    'github:452MJ/react-native-fast-image': 'react-native-fast-image. 🚩 FastImage, performant React Native image component.',
#    'github:facebook/react-native': 'react-native. A framework for building native applications using React',
#    'github:452MJ/AwesomeTemplate': '',
#    'github:substrate-developer-hub/substrate-docs': 'substrate-docs. Substrate Developer Hub. Substrate is powered by best in class cryptographic research and comes with peer to peer networking, consensus mechanisms, and much more.',
#    'github:452MJ/react-native-video-player': 'react-native-video-player. A video player for React Native with controls',
#    'github:452MJ/react-native-easy-toast': '',
#    'github:452MJ/react-native-qrcode-local-image': 'react-native-qrcode-local-image. A local qrcode image parse for react-native',
#    'github:jpush/jmessage-react-plugin': '',
#    'github:452MJ/react-native-fast-image-jerry': 'react-native-fast-image. 🚩 FastImage, performant React Native image component.',
#    'github:remobile/react-native-qrcode-local-image': 'react-native-qrcode-local-image. A local qrcode image parse for react-native',
#    'github:452MJ/react-native-syan-image-picker': 'react-native-syan-image-picker. React-Native 多图片选择 支持裁剪 压缩',
#    'github:452MJ/jpush-react-native': "jpush-react-native. JPush's officially supported React Native plugin (Android & iOS). 极光推送官方支持的 React Native 插件（Android & iOS）。",
#    'github:452MJ/jcore-react-native': '',
#    'github:452MJ/react-native-marquee-ab': 'react-native-marquee-ab. react-native 水平/竖直滚动跑马灯。支持多个text数据，支持点击事件回调，自定义宽度、样式。',
#    'github:452MJ/jerry-lottery-contracts': '',
#    'github:452MJ/Awesome-Template': '',
#    'github:452MJ/jerry-substrate-front-end': '',
#    'github:452MJ/jerry-substrate-node': '',
#    'github:452MJ/metamask-mobile': 'metamask-mobile. Mobile web browser providing access to websites that use the Ethereum blockchain',
#    'github:452MJ/react-native-alipay-jerry': 'react-native-alipay-jerry. 基于 React Native 的宝支付包，已更新到最新的支付宝 SDK 版本，支持Android/iOS。',
#    'github:452MJ/ant-design-mobile-rn': 'ant-design-mobile-rn. Ant Design for React Native',
#    'github:452MJ/jerhel-website': '',
#    'github:452MJ/jerhel-backend': '',
#    'github:452MJ/react-native-http-cache': 'react-native-http-cache. Native module to control react native http cache',
#    'github:452MJ/452MJ': '',
#    'github:452MJ/react-native-svg-charts-examples': 'react-native-svg-charts-examples. A collection of usage examples of react-native-svg-charts',
#    'github:452MJ/react-native-pomelo': '',
#    'github:452MJ/react-native-zharev-pomelo': '',
#    'github:452MJ/substrate-docs': '',
#    'github:452MJ/react-native-af-video-player': '',
#    'github:452MJ/SDWebImage': 'SDWebImage. Asynchronous image downloader with cache support as a UIImageView category',
#    'github:452MJ/react-native': '',
#    'github:452MJ/CryptoCurrency': '',
#    'github:452MJ/yinhao-demo': '',
#    'github:452MJ/react-native-orientation-jerry': 'react-native-orientation-jerry. Listen to device orientation changes in react-native and set preferred orientation on screen to screen basis.',
#    'github:452MJ/auto-green': ''}},
#  {'id': 'github:cpojer',
#   'type': 'B',
#   'projects': {'github:joltup/rn-fetch-blob': 'rn-fetch-blob. A project committed to making file access and data transfer easier, efficient for React Native developers.',
#    'github:facebook/react-native': 'react-native. A framework for building native applications using React',
#    'github:facebook/metro': 'metro. 🚇 The JavaScript bundler for React Native',
#    'github:rome/tools': 'tools. Unified developer tools for JavaScript, TypeScript, and the web',
#    'github:facebook/react-native-website': 'react-native-website. The React Native website and docs',
#    'github:facebook/jest': 'jest. Delightful JavaScript Testing.',
#    'github:facebook/fbjs': 'fbjs. A collection of utility libraries used by other Meta JS projects.',
#    'github:cpojer/js-codemod': 'js-codemod. Codemod scripts to transform code to next generation JS',
#    'github:react-native-community/react-native-segmented-control': 'segmented-control. React Native SegmentedControl library',
#    'github:react-native-community/react-native-progress-bar-android': 'progress-bar-android. ProgressBar Component for react-native Android',
#    'github:jjppof/goldensun_html5': 'goldensun_html5. An online Golden Sun Engine entirely built in HTML5 with Phaser 2. Check https://gshtml5.org/',
#    'github:facebook/react': 'react. The library for web and native user interfaces.',
#    'github:sp1thas/dropboxignore': "dropboxignore. [MIRROR OF https://codeberg.org/sp1thas/dropboxignore] It's all about the missing .dropboxignore file.",
#    'github:vitejs/vite': "vite. Next generation frontend tooling. It's fast!",
#    'github:reactjs/reactjs.org': 'react.dev. The React documentation website',
#    'github:facebook/relay': 'relay. Relay is a JavaScript framework for building data-driven React applications.',
#    'github:cpojer/vite-ts-react-tailwind-template': 'vite-ts-react-tailwind-template. Minimal, sensible defaults, fast.',
#    'github:yarnpkg/yarn': 'yarn. The 1.x line is frozen - features and bugfixes now happen on https://github.com/yarnpkg/berry',
#    'github:facebook/fbt': 'fbt. A JavaScript Internationalization Framework',
#    'github:react-native-sensors/react-native-sensors': 'react-native-sensors. A developer friendly approach for sensors in React Native',
#    'github:react-native-community/react-native-progress-view': 'progress-view. ProgressView Component for react-native iOS/macOS/Windows',
#    'github:jest-community/jest-watch-typeahead': 'jest-watch-typeahead. Jest watch plugin for filtering test by file name or test name',
#    'github:facebook/jscodeshift': 'jscodeshift. A JavaScript codemod toolkit.',
#    'github:cpojer/profane': 'profane. Zero dependency profanity detector.',
#    'github:react-native-community/cli': 'cli. The React Native Community CLI - command line tools to help you build RN apps',
#    'github:ryanburgess/engineer-manager': 'engineer-manager. A list of engineering manager resource links.',
#    'github:facebookincubator/redux-react-hook': 'redux-react-hook. React Hook for accessing state and dispatch from a Redux store',
#    'github:sergioramos/remark-prism': 'remark-prism. Syntax highlighter for markdown code blocks using Prism',
#    'github:immerjs/immer': 'immer. Create the next immutable state by mutating the current one',
#    'github:cpojer/jest': 'jest. Painless JavaScript Unit Testing built on top of the Jasmine test framework.',
#    'github:vitest-dev/vitest': 'vitest. Next generation testing framework powered by Vite.',
#    'github:facebookincubator/idx': 'idx. Library for accessing arbitrarily nested, possibly nullable properties on a JavaScript object.',
#    'github:craftzdog/craftzdog-homepage': 'craftzdog-homepage. My homepage',
#    'github:babel/babel': 'babel. 🐠 Babel is a compiler for writing next generation JavaScript.',
#    'github:romejs/rome': 'tools. Unified developer tools for JavaScript, TypeScript, and the web',
#    'github:mootools/website': 'website. MooTools Website - move fast and break things',
#    'github:cpojer/tools': 'tools. The Rome Toolchain. A linter, compiler, bundler, and more for JavaScript, TypeScript, HTML, Markdown, and CSS.',
#    'github:cpojer/cpojer': '',
#    'github:cpojer/jest-bundler': 'jest-bundler. The famous jest-bundler.',
#    'github:cpojer/best-test-framework': 'best-test-framework. The best test framework.',
#    'github:cdsanchez/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:lencioni/jest': '',
#    'github:cpojer/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:cpojer/palette-swap': 'palette-swap. Image palette swapping and color replacement tool based on canvas for Node.js and browsers.',
#    'github:cpojer/immutable-js': '',
#    'github:cpojer/dotfiles': 'dotfiles. My dotfiles and VS Code setup.',
#    'github:cpojer/licht-theme': 'licht-theme. A comfortable light theme for VS Code, SublimeText, Atom and TextMate.',
#    'github:cpojer/dunkel-theme': 'dunkel-theme. A comfortable high-contrast dark theme for VS Code.',
#    'github:cpojer/react-native': 'react-native. A framework for building native apps with React.',
#    'github:cpojer/react': 'react. React is a JavaScript library for building user interfaces.',
#    'github:kiliman/react-native-website': '',
#    'github:cpojer/delta': 'delta. A syntax-highlighting pager for git, diff, and grep output',
#    'github:react-native-community/rxjs': 'rxjs. A reactive programming library for JavaScript',
#    'github:Naturalclar/react-native-segmented-control': 'react-native-segmented-control. React Native SegmentedControlIos library. Use SegmentedControlIOS to render a UISegmentedControl iOS.',
#    'github:Naturalclar/react-native-progress-bar-android': '',
#    'github:divyanshu013/react-native-website': '',
#    'github:cpojer/react-native-view-shot': 'react-native-view-shot. Snapshot a React Native view and save it to an image',
#    'github:cpojer/react-native-website': 'react-native-website. The site and docs for React Native',
#    'github:brunobar79/react-native': 'react-native. A framework for building native apps with React.',
#    'github:cpojer/copy-as-markdown': 'copy-as-markdown. A React hook to copy text as Markdown.',
#    'github:cpojer/rn-fetch-blob': 'rn-fetch-blob. A project committed to making file access and data transfer easier, efficient for React Native developers.',
#    'github:cpojer/sprites': '',
#    'github:cpojer/dropboxignore': "dropboxignore. It's all about the missing .dropboxignore file.",
#    'github:cpojer/fbjs': 'fbjs. A collection of utility libraries used by other Facebook JS projects.',
#    'github:gedeagas/react-native-website': 'react-native-website. The site and docs for React Native',
#    'github:cpojer/vite': "vite. Next generation frontend tooling. It's fast!",
#    'github:connectdotz/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:cpojer/reactjs.org': '',
#    'github:cpojer/react-native-calendars': 'react-native-calendars. React Native Calendar Components 📆 ',
#    'github:cpojer/vitest': "vitest. A Vite-native test framework. It's fast!",
#    'github:michaelmwu/jest': 'jest. Delightful JavaScript Testing.',
#    'github:raejin/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:cpojer/xdate': 'xdate. A Modern JavaScript Date Library',
#    'github:cpojer/fbt': 'fbtee. The JavaScript & React Internationalization Framework.',
#    'github:cpojer/react-native-sensors': 'react-native-sensors. A developer friendly approach for sensors in React Native',
#    'github:react-native-community/protobuf.js': 'protobuf.js. Protocol Buffers for JavaScript (& TypeScript).',
#    'github:react-native-community/react-native-translucent-modal': 'react-native-translucent-modal. A library for React Native translucent modal',
#    'github:cpojer/jest-watch-typeahead': 'jest-watch-typeahead. Jest watch plugin for filtering test by file name or test name',
#    'github:cpojer/jscodeshift': 'jscodeshift. A JavaScript codemod toolkit.',
#    'github:cpojer/relay': 'relay. Relay is a JavaScript framework for building data-driven React applications.',
#    'github:cpojer/discussions': '',
#    'github:cpojer/react-native-heading': 'react-native-heading. Get device heading information on iOS or Android',
#    'github:cpojer/react-native-gesture-handler': 'react-native-gesture-handler. Declarative API exposing platform native touch and gesture system to React Native.',
#    'github:SimenB/jest': 'jest. 🃏 Painless JavaScript Testing.',
#    'github:cpojer/watch': 'watch. Utilities for watching file trees in node.js',
#    'github:acoates-ms/react-native': 'react-native. A framework for building native apps with React.',
#    'github:cpojer/remark-prism': 'remark-prism. Syntax highlighter for markdown code blocks using Prism',
#    'github:cpojer/immer': 'immer. Create the next immutable state by mutating the current one',
#    'github:cpojer/craftzdog-homepage': 'craftzdog-homepage. My homepage',
#    'github:liorJuice/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:qihaomah/metro': 'metro. 🚇 The JavaScript bundler for React Native.',
#    'github:Naturalclar/react-native': 'react-native. A framework for building native apps with React.',
#    'github:cpojer/babel': 'babel. Babel is a compiler for writing next generation JavaScript.'}}]

# %%
while True:
    try:
        manager()
    except EXP_END_OF_DATA:
        break

#manager.data
